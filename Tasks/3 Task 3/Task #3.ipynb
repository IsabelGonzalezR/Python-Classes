# %%
pip install matplotlib

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **1.Datos de la Copa de fútbol masculina**

# %%
partidos_fifa_copa_mundial= pd.read_csv('https://raw.githubusercontent.com/cienciadedatos/datos-de-miercoles/master/datos/2019/2019-04-10/partidos.txt', delimiter = '\t')
partidos_fifa_copa_mundial.head()
# Out:
#    anio anfitrion                 estadio      ciudad partido_orden  \
# 0  1930   Uruguay         Estadio Pocitos  Montevideo           (1)
# 1  1930   Uruguay  Estadio Parque Central  Montevideo           (2)
# 2  1930   Uruguay  Estadio Parque Central  Montevideo           (3)
# 3  1930   Uruguay         Estadio Pocitos  Montevideo           (4)
# 4  1930   Uruguay  Estadio Parque Central  Montevideo           (5)
#
#         fecha        equipo_1 equipo_2  equipo_1_final  equipo_2_final
# 0  1930-07-13         Francia   Mexico               4               1
# 1  1930-07-13  Estados Unidos  Bélgica               3               0
# 2  1930-07-14      Yugoslavia   Brasil               2               1
# 3  1930-07-14         Rumania     Perú               3               1
# 4  1930-07-15       Argentina  Francia               1               0

# %%
# Nombres de los equipos
equipos_1 = partidos_fifa_copa_mundial['equipo_1']
equipos_2 = partidos_fifa_copa_mundial['equipo_2']
todos_equipos = pd.concat([equipos_1, equipos_2])

# %%
equipos_unicos = todos_equipos.unique()

# %%
equipos_unicos_lista = equipos_unicos.tolist()
print("Equipos que compitieron en la Copa mundial Masculina:")
print(equipos_unicos_lista)
# Out:
# Equipos que compitieron en la Copa mundial Masculina:
# ...

# %%
equipos_1 = partidos_fifa_copa_mundial['equipo_1']
equipos_2 = partidos_fifa_copa_mundial['equipo_2']
todos_equipos = pd.concat([equipos_1, equipos_2])

# Conteo de numero de juegos por equipo
conteo_equipos = todos_equipos.value_counts()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
print("Número de partidos jugados por cada país:")
print(conteo_equipos)
# Out:
# Número de partidos jugados por cada país:
# Brasil                          109
# Italia                           83
# Argentina                        81
# Inglaterra                       69
# Francia                          66
# España                           63
# Alemania occidental              62
# Mexico                           57
# Uruguay                          56
# Suecia                           51
# Países Bajos                     50
# Bélgica                          48
# Alemania                         47
# Yugoslavia                       37
# Suiza                            37
# Corea del Sur                    34
# Polonia                          34
# Chile                            33
# Estados Unidos                   33
# Hungría                          32
# Unión Soviética                  31
# Checoslovaquia                   30
# Portugal                         30
# Austria                          29
# Paraguay                         27
# ...

# %% [markdown]
# **2. Comparativa entre Rusia y Ecuador**

# %%
# Partidos totales Alemania
partidos_Rusia = partidos_fifa_copa_mundial[
    (partidos_fifa_copa_mundial['equipo_1'] == 'Rusia') | (partidos_fifa_copa_mundial['equipo_2'] == 'Rusia')]
# Partidos totales Ecuador
partidos_Ecuador = partidos_fifa_copa_mundial[
    (partidos_fifa_copa_mundial['equipo_1'] == 'Ecuador') | (partidos_fifa_copa_mundial['equipo_2'] == 'Ecuador')]
#Partidos totales por equipo
partidos_Rusia_total = len(partidos_Rusia)
partidos_Ecuador_total = len(partidos_Ecuador)

print(f'Rusia jugó un total de {partidos_Rusia_total} partidos.')
print(f'Ecuador jugó un total de {partidos_Ecuador_total} partidos.')
# Out:
# Rusia jugó un total de 14 partidos.
# Ecuador jugó un total de 10 partidos.

# %%
# Partidos totales en los que Rusia participó
partidos_Rusia_total = partidos_fifa_copa_mundial[(partidos_fifa_copa_mundial['equipo_1'] == 'Rusia') | (partidos_fifa_copa_mundial['equipo_2'] == 'Rusia')]
partidos_Rusia_total= partidos_Rusia_total.sort_values('fecha')

# %%
# Participación de Rusia en la Copa Mundial
plt.plot(partidos_Rusia_total['fecha'], range(1, len(partidos_Rusia_total) + 1), marker='o', linestyle='-', color='purple', label='Rusia')
plt.title('Participación de Rusia en la Copa Mundial')
plt.xlabel('Fechas de los Partidos')
plt.ylabel('Número de Partidos')
plt.legend() 
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
plt.savefig('mi_figura.tiff') #Guardando Figura

# %%
# Partidos totales en los que Ecuador participó
partidos_Ecuador_total = partidos_fifa_copa_mundial[(partidos_fifa_copa_mundial['equipo_1'] == 'Ecuador') | (partidos_fifa_copa_mundial['equipo_2'] == 'Ecuador')]
partidos_Ecuador_total = partidos_Ecuador_total.sort_values('fecha')

# %%
# Participación de Ecuador en la Copa Mundial
plt.plot(partidos_Ecuador_total['fecha'], range(1, len(partidos_Ecuador_total) + 1), marker='o', linestyle='-', color='green', label='Ecuador')
plt.title('Participación de Ecuador en la Copa Mundial')
plt.xlabel('Fechas de los Partidos')
plt.ylabel('Número de Partidos')
plt.legend() 
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
plt.savefig('mi_figura.tiff') #Guardando Figura

# %% [markdown]
# **2.a Gráfico 1.Comparativa de Participación de Rusia y Ecuador en la copa mundial**

# %%
import matplotlib.pyplot as plt

# Supongamos que tienes DataFrames 'partidos_Rusia_total' y 'partidos_Ecuador_total' ordenados por fecha

plt.figure(figsize=(10, 5))  # Tamaño del gráfico

# Crear el gráfico de línea para Rusia
plt.plot(partidos_Rusia_total['fecha'], range(1, len(partidos_Rusia_total) + 1), marker='o', linestyle='-', color='purple', label='Rusia')

# Crear el gráfico de línea para Ecuador
plt.plot(partidos_Ecuador_total['fecha'], range(1, len(partidos_Ecuador_total) + 1), marker='o', linestyle='-', color='green', label='Ecuador')

# Personalizar el gráfico (títulos, etiquetas, leyenda, etc.)
plt.title('Participación de Rusia y Ecuador en la Copa Mundial')
plt.xlabel('Fechas de los Partidos')
plt.ylabel('Número de Partidos')
plt.legend()  # Mostrar la leyenda

# Mostrar el gráfico
plt.xticks(rotation=45)
plt.grid(True)  # Mostrar una cuadrícula
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\BIENBENIDOS UNEMI\Desktop\Rocio\R\Python-Classes\Tasks\3 Task 3\Task #3.ipynb Cell 18 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/BIENBENIDOS%20UNEMI/Desktop/Rocio/R/Python-Classes/Tasks/3%20Task%203/Task%20%233.ipynb#X46sZmlsZQ%3D%3D?line=7'>8</a> plt.plot(partidos_Rusia_total['fecha'], range(1, len(partidos_Rusia_total) + 1), marker='o', linestyle='-', color='purple', label='Rusia')
#      <a href='vscode-notebook-cell:/c%3A/Users/BIENBENIDOS%20UNEMI/Desktop/Rocio/R/Python-Classes/Tasks/3%20Task%203/Task%20%233.ipynb#X46sZmlsZQ%3D%3D?line=9'>10</a> # Crear el gráfico de línea para Ecuador
# ...

# %% [markdown]
# **2.2 Gráfico 2.Los datos de los paises aparezcan en un subgráfico diferente**

# %% [markdown]
# **Se comparan ambos paises por equipos final 1, solo muestra un solo ano por fecha**

# %%
fig=plt.figure()
eje=fig.add_subplot(1,2,1)
partidos_paises[partidos_paises['anfitrion']=='España'].plot(x = 'fecha',y = 'equipo_1_final',ax = eje,linestyle = '--', color = 'green')
#Agrega el segundo eje
eje2 = fig.add_subplot(1, 2, 2, sharey = eje)
partidos_paises[partidos_paises['anfitrion']=='Alemania'].plot(x = 'fecha',y = 'equipo_1_final',ax = eje2,linestyle= 'dotted', color = 'blue')
eje.set_xlabel('España')
eje2.set_xlabel('Alemania')
eje.set_ylabel('equipo_1_final')
plt.title('Comparación  gráficos por paises España y Alemania partidos final 1')
plt.savefig('mi_figura.tiff')

# %% [markdown]
# **Comparar dos paises por equipo final 2**

# %%
fig=plt.figure()
eje=fig.add_subplot(1,2,1)
partidos_paises[partidos_paises['anfitrion']=='España'].plot(x = 'fecha',y = 'equipo_2_final',ax = eje,linestyle = 'dotted', color = 'red')
#Agrega el segundo eje
eje2 = fig.add_subplot(1, 2, 2, sharey = eje)
partidos_paises[partidos_paises['anfitrion']=='Alemania'].plot(x = 'fecha',y = 'equipo_2_final',ax = eje2,linestyle= 'dotted', color = 'orange')
eje.set_xlabel('España')
eje2.set_xlabel('Alemania')
eje.set_ylabel('equipo_2_final')
plt.title('Comparación  gráficos de España y Alemania partidos final 2')
plt.savefig('mi_figura.tiff')
